# %%
import sys
import torch
import transformers

print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("Transformers:", transformers.__version__)
# Out:
# Python: 3.10.20 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:13:20) [MSC v.1942 64 bit (AMD64)]
# PyTorch: 2.13.0+cpu
# Transformers: 5.14.1

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

print("BLIP libraries are working!")
# Out:
# BLIP libraries are working!

# %%
processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

print("Model loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Model loaded successfully!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sachi\Contacts\Gen AI

# %%
Image.open("dog.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1137x947>

# %%
image = Image.open("dog.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a small white dog standing in the grass

# %%
Image.open("bird.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x365>

# %%
image = Image.open("bird.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a small bird perched on a branch

# %%
Image.open("car.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=738x414>

# %%
image = Image.open("car.jpeg").convert("RGB")

inputs = processor(images=image, return_tensors="pt")

output = model.generate(**inputs, max_new_tokens=30)

caption = processor.decode(
    output[0],
    skip_special_tokens=True
)

print("Generated Caption:", caption)
# Out:
# Generated Caption: the mercedes e - class electric concept
