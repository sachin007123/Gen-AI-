# %%
# !pip install transformers torch -q
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-498' coro=<_async_in_context.<locals>.run_in_context_pre311() done, defined at C:\AIML\envs\DL\lib\site-packages\ipykernel\utils.py:76> wait_for=<Task pending name='Task-499' coro=<_async_in_context.<locals>.preserve_context() running at C:\AIML\envs\DL\lib\site-packages\ipykernel\utils.py:68> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at C:\AIML\envs\DL\lib\site-packages\zmq\eventloop\zmqstream.py:563]>
# C:\AIML\envs\DL\lib\threading.py:995: RuntimeWarning: coroutine '_async_in_context.<locals>.preserve_context' was never awaited
#   with _shutdown_locks_lock:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-499' coro=<_async_in_context.<locals>.preserve_context() running at C:\AIML\envs\DL\lib\site-packages\ipykernel\utils.py:68> cb=[Task.task_wakeup()]>

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
model_name = "distilgpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
tokenizer.pad_token = tokenizer.eos_token

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
def generate_text(prompt, max_length=100):
    inputs = tokenizer(prompt, return_tensors="pt")

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_length=max_length,
            num_return_sequences=1,
            do_sample=True,
            temperature=0.7,
            top_k=50,
            top_p=0.95,
            pad_token_id=tokenizer.eos_token_id
        )

    generated_text = tokenizer.decode(
        output[0],
        skip_special_tokens=True
    )

    return generated_text

# %%
prompt = input("Enter a sentence or topic: ")

result = generate_text(prompt)

print("\nGenerated Text:")
print(result)
# Out:
# Enter a sentence or topic:  Fake News Detection using AI
# Generated Text:
# Fake News Detection using AI to detect fake news

# %%
prompts = [
    "Artificial Intelligence is changing the world",
    "The future of technology",
    "A student started learning Python"
]

for prompt in prompts:
    print("\nInput:", prompt)
    print("Generated Text:")
    print(generate_text(prompt))
    print("-" * 70)
# Out:
# Input: Artificial Intelligence is changing the world
# Generated Text:
# Artificial Intelligence is changing the world. It’s changing the world. It’s changing the world. It’s changing the world.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------------------------------------
#
# Input: The future of technology
# Generated Text:
# The future of technology is not easy. However, we need to understand the implications of the technology and how it affects the environment and the environment. We need to understand the implications of the technology and how it affects the environment and the environment. We need to understand the implications of the technology and how it affects the environment and the environment. We need to understand the implications of the technology and how it affects the environment and the environment. We need to understand the implications of the technology and how it affects the
# ----------------------------------------------------------------------
#
# Input: A student started learning Python
# Generated Text:
# A student started learning Python and Python. He worked as a teacher at a local college in Oregon, where he received a BA in Applied Mathematics from the University of Idaho.
#
#
#
# "I was a bit surprised when I saw that the students were using Python," said Lee Miller, a professor of mathematics at the University of Idaho. "It was really interesting to see how well they're doing with Python and Python. I don't know if that's a good thing. But there's a
# ----------------------------------------------------------------------

# %%
while True:
    prompt = input("\nEnter a topic (or type 'exit' to stop): ")

    if prompt.lower() == "exit":
        print("Program stopped.")
        break

    print("\nGenerated Text:")
    print(generate_text(prompt))
# Out:
# Enter a topic (or type 'exit' to stop):  AI Chatbot for Student Assistance
# Generated Text:
# AI Chatbot for Student Assistance Programs (GATS)
# Enter a topic (or type 'exit' to stop):  "A student started learning Python"
# Generated Text:
# "A student started learning Python" in his class, and he told the student he would have to learn Python in the future."He said, "I can't wait to learn Python in the future."
#
#
#
#
# After the course was over, his class began. "I got to a point where I was just trying to be a student," he said. "I thought, 'Wow, this is great, this is really cool.'"
# The next day, he went on to
# Enter a topic (or type 'exit' to stop):  "The future of technology",
# Generated Text:
# "The future of technology", he said.
#
#
#
# "We're not ready to go into the future, but we're ready to go into the future. There is a lot of energy and energy available to be put into making the future of technology.
# "We're going to have to do more to do that, but we're going to have to have to do more to do that.
# "We need to do more to make it sustainable.
# "We need to do
# Enter a topic (or type 'exit' to stop):  Artificial Intelligence is changing the world
# Generated Text:
# Artificial Intelligence is changing the world and it’s going to be a very difficult one.
#
#
#
# It was a big step forward, but the next step is to get more data to understand how the world works.
# That’s why a paper published today in the journal Nature Communications is showing that artificial intelligence can make us smarter.
# The artificial intelligence technology could help us find a way to understand the world around us.
# "The artificial intelligence technology could help us understand
# Enter a topic (or type 'exit' to stop):  stop
# Generated Text:
# stop the next day, or maybe the next day.”
# Enter a topic (or type 'exit' to stop):  exit
# Program stopped.
